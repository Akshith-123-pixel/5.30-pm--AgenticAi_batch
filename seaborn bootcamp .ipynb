# %%
'welcome to bootcamp by nareshit'
# Out:
# 'welcome to bootcamp by nareshit'

# %%
#pip install --upgrade seaborn

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.get_dataset_names()
#
# NameError: name 'sns' is not defined

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tips = sns.load_dataset("tips")
#       2 tips.head()
#
# NameError: name 'sns' is not defined

# %%
#pip.install--upgrade.seaborn

# %%
import.warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
#   Cell In[19], line 1
#     import.warnings
#           ^
# SyntaxError: invalid syntax

# %%
import.warnings
warnings.filterwarnings("ignore", category=FutureWarning).
# Out:
#   Cell In[21], line 1
#     import.warnings
#           ^
# SyntaxError: invalid syntax

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\teja 12\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\teja 12\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\teja 12\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\teja 12\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\teja 12\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\teja 12\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\teja 12\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\teja 12\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sins.load_datsset("tips")
tipshead()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 tips = sins.load_datsset("tips")
#       2 tipshead()
#
# NameError: name 'sins' is not defined

# %%
tips = sns.load_datsset("tips")
tipshead()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 tips = sns.load_datsset("tips")
#       2 tipshead()
#
# AttributeError: module 'seaborn' has no attribute 'load_datsset'

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme(style="darkgrid")

# %%
tips.to_csv("tips_dataset.csv",index=False)
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\teja 12'

# %%
sns.barplot(data=tips,x='day',y='total_bill',hue='sex',pallete='muted')
plt.title("Barplot of Total Bill by day")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 sns.barplot(data=tips,x='day',y='total_bill',hue='sex',pallete='muted')
#       2 plt.title("Barplot of Total Bill by day")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1315, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1312 else:
#    1313     kws.update(color=main_color, edgecolor=main_color, facecolor="none")
# -> 1315 bar_func(**{**kws, **plot_kws})
#    1317 if aggregator.error_method is not None:
#    1318     self.plot_errorbars(
#    1319         ax, agg_data, capsize,
#    1320         {"color": ".26" if fill else main_color, **err_kws}
#    1321     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2591, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2582 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2583     r = mpatches.Rectangle(
#    2584         xy=(l, b), width=w, height=h,
#    2585         facecolor=c,
#    (...)
#    2589         hatch=htch,
#    2590         )
# -> 2591     r._internal_update(kwargs)
#    2592     r.get_path()._interpolation_steps = 100
#    2593     if orientation == 'vertical':
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'pallete'

# %%
sns.barplot(data=tips,x='day',y='total_bill',hue='sex',palette='muted')
plt.title("Barplot of Total Bill by day")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 sns.barplot(data=tips,x='day',y='total_bill',hue='sex',palette='muted')
# ----> 2 plt.title("Barplot of Total Bill by day")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(data=tips,x='day',y='total_bill',hue='sex',pallete='muted')
plt.title("Barplot of Total Bill by day")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 sns.barplot(data=tips,x='day',y='total_bill',hue='sex',pallete='muted')
#       2 plt.title("Barplot of Total Bill by day")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1315, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1312 else:
#    1313     kws.update(color=main_color, edgecolor=main_color, facecolor="none")
# -> 1315 bar_func(**{**kws, **plot_kws})
#    1317 if aggregator.error_method is not None:
#    1318     self.plot_errorbars(
#    1319         ax, agg_data, capsize,
#    1320         {"color": ".26" if fill else main_color, **err_kws}
#    1321     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2591, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2582 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2583     r = mpatches.Rectangle(
#    2584         xy=(l, b), width=w, height=h,
#    2585         facecolor=c,
#    (...)
#    2589         hatch=htch,
#    2590         )
# -> 2591     r._internal_update(kwargs)
#    2592     r.get_path()._interpolation_steps = 100
#    2593     if orientation == 'vertical':
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'pallete'

# %%
sns.lineplot(data=tips,x='size',y='total_bill',hue='sex',ci=None,markers='o')
plt.title("lineplot of Total Bill vs size")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 sns.lineplot(data=tips,x='size',y='total_bill',hue='sex',ci=None,markers='o')
# ----> 2 plt.title("lineplot of Total Bill vs size")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.boxplot(data=tips,x='day',y='tip',hue='time',split=True,palette='pastel')
plt.title("violin plot of total bill by day and time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sns.boxplot(data=tips,x='day',y='tip',hue='time',split=True,palette='pastel')
#       2 plt.title("violin plot of total bill by day and time")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)
#     697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# TypeError: Axes.bxp() got an unexpected keyword argument 'split'

# %%
sns.violinplot(data=tips,x='day',y='total_bill',hue='time',split=True,palette='pastel')
plt.title("violin plot of total bill by day and time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 sns.violinplot(data=tips,x='day',y='total_bill',hue='time',split=True,palette='pastel')
# ----> 2 plt.title("violin plot of total bill by day and time")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.boxplot(data=tips,x='day',y='tip',hue='smoker',palette='set2')
plt.title("boxplot of tips by day and smoker status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:62, in get_colormap(name)
#      61 try:
# ---> 62     return mpl.colormaps[name]
#      63 except AttributeError:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:91, in ColormapRegistry.__getitem__(self, item)
#      90 except KeyError:
# ---> 91     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'set2' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.boxplot(data=tips,x='day',y='tip',hue='smoker',palette='set2')
#       2 plt.title("boxplot of tips by day and smoker status")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1626, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1623 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
#    1625 saturation = saturation if fill else 1
# -> 1626 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:838, in VectorPlotter.map_hue(self, palette, order, norm, saturation)
#     837 def map_hue(self, palette=None, order=None, norm=None, saturation=1):
# --> 838     mapping = HueMapping(self, palette, order, norm, saturation)
#     839     self._hue_map = mapping
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:150, in HueMapping.__init__(self, plotter, palette, order, norm, saturation)
#     147 elif map_type == "categorical":
#     149     cmap = norm = None
# --> 150     levels, lookup_table = self.categorical_mapping(
#     151         data, palette, order,
#     152     )
#     154 # --- Option 3: datetime mapping
#     155
#     156 else:
#     157     # TODO this needs actual implementation
#     158     cmap = norm = None
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:248, in HueMapping.categorical_mapping(self, data, palette, order)
#     246         colors = self._check_list_length(levels, palette, "palette")
#     247     else:
# --> 248         colors = color_palette(palette, n_colors)
#     250     lookup_table = dict(zip(levels, colors))
#     252 return levels, lookup_table
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:237, in color_palette(palette, n_colors, desat, as_cmap)
#     235             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 237             raise ValueError(f"{palette!r} is not a valid palette name")
#     239 if desat is not None:
#     240     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: 'set2' is not a valid palette name

# %%
sns.regplot(data=tips,x='total_bill',y='tip',scatter_kws={'s':50},line_kws={'color':'red'})
plt.title("regression plot of Total bill vs tip")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 sns.regplot(data=tips,x='total_bill',y='tip',scatter_kws={'s':50},line_kws={'color':'red'})
# ----> 2 plt.title("regression plot of Total bill vs tip")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(data=tips,x='total_bill',bins=20,kde=True,color='blue')
plt.title("Histogram of total bill with KDE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 sns.histplot(data=tips,x='total_bill',bins=20,kde=True,color='blue')
# ----> 2 plt.title("Histogram of total bill with KDE")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.pairplot(tips,hue='sex',vars=["total_bill","tip","size"],palette='husl')
plt.suptitle("pair plot:numeric variables by gender",y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 2
#       1 sns.pairplot(tips,hue='sex',vars=["total_bill","tip","size"],palette='husl')
# ----> 2 plt.suptitle("pair plot:numeric variables by gender",y=1.02)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.catplot(data=tips,x='day',y='tip',hue='sex',kind='point',palette='bright')
plt.title("catplot(point):Tips by day and gender")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 sns.catplot(data=tips,x='day',y='tip',hue='sex',kind='point',palette='bright')
# ----> 2 plt.title("catplot(point):Tips by day and gender")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',palette='coolwarm')
plt.suptitle("jointplot:Total Bill vs Tip",y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 sns.jointplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',palette='coolwarm')
# ----> 2 plt.suptitle("jointplot:Total Bill vs Tip",y=1.02)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
g = sns.FaceGrid(tips,col='time,row'smoker',margin_titles=True).map(sns.histplot,'total_bill',bins=20,kde=True).add_legend()g
# Out:
#   Cell In[88], line 1
#     g = sns.FaceGrid(tips,col='time,row'smoker',margin_titles=True).map(sns.histplot,'total_bill',bins=20,kde=True).add_legend()g
#                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
sns.stripplot(data=tips,x='day',y='tip',hue='sex',jitter=True,palette='set1')
plt.title("strip plot:Tips by data and gender")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:62, in get_colormap(name)
#      61 try:
# ---> 62     return mpl.colormaps[name]
#      63 except AttributeError:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:91, in ColormapRegistry.__getitem__(self, item)
#      90 except KeyError:
# ---> 91     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'set1' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 sns.stripplot(data=tips,x='day',y='tip',hue='sex',jitter=True,palette='set1')
#       2 plt.title("strip plot:Tips by data and gender")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2106, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2103 hue_order = p._palette_without_hue_backcompat(palette, hue_order)
#    2104 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
# -> 2106 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2107 color = _default_color(ax.scatter, hue, color, kwargs)
#    2108 edgecolor = p._complement_color(edgecolor, color, p._hue_map)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:838, in VectorPlotter.map_hue(self, palette, order, norm, saturation)
#     837 def map_hue(self, palette=None, order=None, norm=None, saturation=1):
# --> 838     mapping = HueMapping(self, palette, order, norm, saturation)
#     839     self._hue_map = mapping
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:150, in HueMapping.__init__(self, plotter, palette, order, norm, saturation)
#     147 elif map_type == "categorical":
#     149     cmap = norm = None
# --> 150     levels, lookup_table = self.categorical_mapping(
#     151         data, palette, order,
#     152     )
#     154 # --- Option 3: datetime mapping
#     155
#     156 else:
#     157     # TODO this needs actual implementation
#     158     cmap = norm = None
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:248, in HueMapping.categorical_mapping(self, data, palette, order)
#     246         colors = self._check_list_length(levels, palette, "palette")
#     247     else:
# --> 248         colors = color_palette(palette, n_colors)
#     250     lookup_table = dict(zip(levels, colors))
#     252 return levels, lookup_table
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:237, in color_palette(palette, n_colors, desat, as_cmap)
#     235             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 237             raise ValueError(f"{palette!r} is not a valid palette name")
#     239 if desat is not None:
#     240     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: 'set1' is not a valid palette name

# %%
sns.kdeplot(data=tips,x='total_bill',hue='sex',fill=True,palette='tab10')
plt.title("kde plot:Total bill density by gender")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 2
#       1 sns.kdeplot(data=tips,x='total_bill',hue='sex',fill=True,palette='tab10')
# ----> 2 plt.title("kde plot:Total bill density by gender")
#       3 plt.show()
#
# NameError: name 'plt' is not defined
